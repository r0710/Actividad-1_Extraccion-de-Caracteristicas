# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
df = pd.read_csv('Boston_libre de atipicos.csv')
df['host_acceptance_rate']=df['host_acceptance_rate'].str.replace('%', '')
df['host_acceptance_rate']= df['host_acceptance_rate'].astype(float)
df['price']=df['price'].str.replace('$', '')
df['price']=df['price'].str.replace(',', '')
df['host_response_rate']=df['host_response_rate'].str.replace('%', '')
df['host_response_rate']= df['host_response_rate'].astype(float)
df['price']= df['price'].astype(float)
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4426 entries, 0 to 4425
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   last_scraped                 4426 non-null   object
#  1   host_since                   4426 non-null   object
#  2   host_location                4426 non-null   object
#  3   host_response_time           4426 non-null   object
#  4   host_response_rate           4426 non-null   float64
#  5   host_acceptance_rate         4426 non-null   float64
#  6   host_is_superhost            4426 non-null   object
#  7   host_neighbourhood           4426 non-null   object
#  8   host_verifications           4426 non-null   object
#  9   host_identity_verified       4426 non-null   object
#  10  neighbourhood                4426 non-null   object
#  11  neighbourhood_cleansed       4426 non-null   object
#  12  property_type                4426 non-null   object
# ...

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t1= freq_tbl(df['host_location'])
t1 = t1.drop(['percentage','cumulative_perc'], axis=1)
t1
#Creamos el filtro de los valores más representativos
f1= t1[t1['frequency']>51]
f1
#Ajustamos el indice del dataframe
f1= f1.set_index('host_location')
f1
# Out:
#                               frequency
# host_location
# Boston, MA                         3210
# New York, NY                        581
# Massachusetts, United States        171

# %%
f1.plot(kind='bar', width = 0.8, figsize=(10,4), color=('red','yellow'))
plt.title('Locaciones más populares de los hosts')
plt.xlabel('Locación')
plt.ylabel('Número de propiedades')
# Out:
# Text(0, 0.5, 'Número de propiedades')

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t2= freq_tbl(df['host_response_time'])
t2 = t2.drop(['percentage','cumulative_perc'], axis=1)
t2
#No creamos un filtro ya que las muestras son representativas
#Ajustamos el indice del dataframe
f2= t2.set_index('host_response_time')
f2
# Out:
#                     frequency
# host_response_time
# within an hour           3720
# within a few hours        443
# within a day              225
# a few days or more         38

# %%
f2['frequency'].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t3= freq_tbl(df['host_is_superhost'])
t3 = t3.drop(['percentage','cumulative_perc'], axis=1)
t3
#No creamos un filtro ya que las muestras son representativas
#Ajustamos el indice del dataframe
f3= t3.set_index('host_is_superhost')
f3
# Out:
#                    frequency
# host_is_superhost
# f                       2985
# t                       1441

# %%
f3.plot(kind='bar', width = 0.8, figsize=(10,4), color=('red','yellow'))
plt.title('¿Cuántos son super-host?')
plt.xlabel('Validación como super-host')
plt.ylabel('Número de propiedades')
# Out:
# Text(0, 0.5, 'Número de propiedades')

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t4= freq_tbl(df['host_neighbourhood'])
t4 = t4.drop(['percentage','cumulative_perc'], axis=1)
t4
#Creamos el filtro de los valores más representativos
f4= t4[t4['frequency']>150]
f4
#Ajustamos el indice del dataframe
f4= f4.set_index('host_neighbourhood')
f4
# Out:
#                     frequency
# host_neighbourhood
# Dorchester                409
# Cambridge                 382
# Beacon Hill               305
# Roxbury                   260
# Downtown                  203
# South End                 188
# Fenway–Kenmore            177
# Allston-Brighton          170
# Jamaica Plain             167
# Fenway/Kenmore            166

# %%
f4.plot(kind='area', figsize=(10,4), alpha = 0.5, xlabel='Barrios más famosos', ylabel='Número de viviendas')
# Out:
# <Axes: xlabel='Barrios más famosos', ylabel='Número de viviendas'>

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t5= freq_tbl(df['room_type'])
t5 = t5.drop(['percentage','cumulative_perc'], axis=1)
t5
#Creamos el filtro de los valores más representativos
f5= t5[t5['frequency']>4]
f5
#Ajustamos el indice del dataframe
f5= f5.set_index('room_type')
f5
# Out:
#                  frequency
# room_type
# Entire home/apt       2999
# Private room          1360
# Hotel room              63

# %%
f5['frequency'].plot(kind='pie', figsize=(10,4), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t6= freq_tbl(df['property_type'])
t6 = t6.drop(['percentage','cumulative_perc'], axis=1)
t6
#Creamos el filtro de los valores más representativos
f6= t6[t6['frequency']>146]
f6
#Ajustamos el indice del dataframe
f6= f6.set_index('property_type')
f6
# Out:
#                              frequency
# property_type
# Entire rental unit                2173
# Private room in rental unit        659
# Private room in home               372
# Entire condo                       322
# Entire home                        224

# %%
f6.plot(kind='bar', width = 0.8, figsize=(10,4), color=('red','yellow'))
plt.title('Tipos de propiedad de los hosts')
plt.xlabel('Tipo de propiedad')
plt.ylabel('Número de propiedades')
# Out:
# Text(0, 0.5, 'Número de propiedades')

# %%
#Decídi que esta variable solo la dejaría en una tabla de frecuencias ya que al contener tanto data realmente sería imposibel manejarlo en una gráfica
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t7= freq_tbl(df['amenities'])
#Creamos el filtro de los valores más representativos
f7= t7[t7['frequency']>14]
f7
#Ajustamos el indice del dataframe
f7= f7.set_index('amenities')
f7
# Out:
#                                                     frequency  percentage  \
# amenities
# ["Smoke alarm", "Coffee maker", "Hangers", "Gym...         39    0.008812
# ["Smoke alarm", "Coffee maker", "Hangers", "Gym...         27    0.006100
# ["Smoke alarm", "Coffee maker", "Hangers", "Gym...         25    0.005648
# ["Smoke alarm", "Clothing storage", "Coffee mak...         19    0.004293
# ["Coffee maker", "Hangers", "Stove", "TV", "Fre...         19    0.004293
# ["Smoke alarm", "Coffee maker", "Hangers", "Gym...         18    0.004067
# ["Smoke alarm", "Coffee maker", "Hangers", "TV"...         16    0.003615
# ["Smoke alarm", "Coffee maker", "Hangers", "TV"...         16    0.003615
#
#                                                     cumulative_perc
# amenities
# ["Smoke alarm", "Coffee maker", "Hangers", "Gym...         0.008812
# ["Smoke alarm", "Coffee maker", "Hangers", "Gym...         0.014912
# ["Smoke alarm", "Coffee maker", "Hangers", "Gym...         0.020560
# ...

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t8= freq_tbl(df['host_since'])
t8 = t8.drop(['percentage','cumulative_perc'], axis=1)
t8
#Creamos el filtro de los valores más representativos
f8= t8[t8['frequency']>68]
f8
#Ajustamos el indice del dataframe
f8= f8.set_index('host_since')
f8
# Out:
#             frequency
# host_since
# 2016-12-16        352
# 2019-09-25        116
# 2018-08-29         93
# 2014-10-09         88
# 2020-01-27         78
# 2019-07-13         77
# 2020-10-28         70

# %%
#Realizamos grafico de área del dataframe filtrado
f8.plot(kind='area', figsize=(10,4),alpha = 0.5, title='Fecha inicial del registro', xlabel='Fecha de registro', ylabel='Host registrados')
# Out:
# <Axes: title={'center': 'Fecha inicial del registro'}, xlabel='Fecha de registro', ylabel='Host registrados'>

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t9= freq_tbl(df['host_identity_verified'])
t9 = t9.drop(['percentage','cumulative_perc'], axis=1)
t9
#Creamos el filtro de los valores más representativos
f9= t9[t9['frequency']>68]
f9
#Ajustamos el indice del dataframe
f9= f9.set_index('host_identity_verified')
f9
# Out:
#                         frequency
# host_identity_verified
# t                            4053
# f                             373

# %%
#Realizamos grafico de pastel del dataframe filtrado
f9["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%", title='Identificación verificada')
# Out:
# <Axes: title={'center': 'Identificación verificada'}, ylabel='frequency'>

# %%
#Creamos una copia para no trabajar sobre el dataframe original
dfc = df.copy()

# %%
#Calculamos el numero total de la población "n"
dfc['host_response_rate']. info()
n1=4426
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4426 entries, 0 to 4425
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 4426 non-null   float64
# dtypes: float64(1)
# memory usage: 34.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
max1=dfc['host_response_rate'].max()
min1=dfc['host_response_rate'].min()
l1= [min1, max1]
l1
# Out:
# [0.0, 100.0]

# %%
r1=max1-min1
ni1= 1+3.32*np.log10(n1)
ni1
# Out:
# 13.104757879842914

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
in1=np.linspace(0.0, 100.01, 14)
in1
# Out:
# array([  0.        ,   7.69307692,  15.38615385,  23.07923077,
#         30.77230769,  38.46538462,  46.15846154,  53.85153846,
#         61.54461538,  69.23769231,  76.93076923,  84.62384615,
#         92.31692308, 100.01      ])

# %%
c1 = ["Muy malo (0 - 7.7)", "Malo (7.7 - 15.4)", "Bajo (15.4 - 23.1)", "Regular (23.1 - 30.8)", 
    "Aceptable (30.8 - 38.5)", "Bueno (38.5 - 46.2)", "Muy bueno (46.2 - 53.9)", "Excelente (53.9 - 61.5)", 
    "Sobresaliente (61.5 - 69.2)", "Excepcional (69.2 - 76.9)", "Increíble (76.9 - 84.6)", "Extraordinario (84.6 - 92.3)", 
    "Perfecto (92.3 - 100)"]

# %%
dfc['host_response_rate']=pd.cut(x= dfc['host_response_rate'], bins=in1, labels= c1)
dfc['host_response_rate']
# Out:
# 0              Perfecto (92.3 - 100)
# 1              Perfecto (92.3 - 100)
# 2              Perfecto (92.3 - 100)
# 3              Perfecto (92.3 - 100)
# 4       Extraordinario (84.6 - 92.3)
#                     ...
# 4421           Perfecto (92.3 - 100)
# 4422           Perfecto (92.3 - 100)
# 4423           Perfecto (92.3 - 100)
# 4424           Perfecto (92.3 - 100)
# 4425           Perfecto (92.3 - 100)
# Name: host_response_rate, Length: 4426, dtype: category
# Categories (13, object): ['Muy malo (0 - 7.7)' < 'Malo (7.7 - 15.4)' < 'Bajo (15.4 - 23.1)' < 'Regular (23.1 - 30.8)' ... 'Excepcional (69.2 - 76.9)' < 'Increíble (76.9 - 84.6)' < 'Extraordinario (84.6 - 92.3)' < 'Perfecto (92.3 - 100)']

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t_1= freq_tbl(dfc['host_response_rate'])
t_1 = t_1.drop(['percentage','cumulative_perc'], axis=1)
t_1
#Creamos el filtro de los valores más representativos
f_1= t_1[t_1['frequency']>21]
#Ajustamos el indice del dataframe
f_1= f_1.set_index('host_response_rate')
f_1
# Out:
#                               frequency
# host_response_rate
# Perfecto (92.3 - 100)              3999
# Extraordinario (84.6 - 92.3)        223
# Increíble (76.9 - 84.6)              76
# Excepcional (69.2 - 76.9)            38

# %%
f_1.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='host_response_rate'>

# %%
#Calculamos el numero total de la población "n"
dfc['host_acceptance_rate']. info()
n2=4426
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4426 entries, 0 to 4425
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 4426 non-null   float64
# dtypes: float64(1)
# memory usage: 34.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
max2=dfc['host_acceptance_rate'].max()
min2=dfc['host_acceptance_rate'].min()
l2= [min2, max2]
l2
# Out:
# [0.0, 100.0]

# %%
r2=max2-min2
ni2= 1+3.32*np.log10(n2)
ni2
# Out:
# 13.104757879842914

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
in2=np.linspace(0.0, 100.01, 14)
in2
# Out:
# array([  0.        ,   7.69307692,  15.38615385,  23.07923077,
#         30.77230769,  38.46538462,  46.15846154,  53.85153846,
#         61.54461538,  69.23769231,  76.93076923,  84.62384615,
#         92.31692308, 100.01      ])

# %%
c2 = ["Muy malo (0 - 7.7)", "Malo (7.7 - 15.4)", "Bajo (15.4 - 23.1)", "Regular (23.1 - 30.8)", 
    "Aceptable (30.8 - 38.5)", "Bueno (38.5 - 46.2)", "Muy bueno (46.2 - 53.9)", "Excelente (53.9 - 61.5)", 
    "Sobresaliente (61.5 - 69.2)", "Excepcional (69.2 - 76.9)", "Increíble (76.9 - 84.6)", "Extraordinario (84.6 - 92.3)", 
    "Perfecto (92.3 - 100)"]

# %%
dfc['host_acceptance_rate']=pd.cut(x= dfc['host_acceptance_rate'], bins=in2, labels= c2)
dfc['host_acceptance_rate']
# Out:
# 0            Bajo (15.4 - 23.1)
# 1         Perfecto (92.3 - 100)
# 2         Perfecto (92.3 - 100)
# 3       Muy bueno (46.2 - 53.9)
# 4       Excelente (53.9 - 61.5)
#                  ...
# 4421      Perfecto (92.3 - 100)
# 4422      Perfecto (92.3 - 100)
# 4423      Perfecto (92.3 - 100)
# 4424      Perfecto (92.3 - 100)
# 4425      Perfecto (92.3 - 100)
# Name: host_acceptance_rate, Length: 4426, dtype: category
# Categories (13, object): ['Muy malo (0 - 7.7)' < 'Malo (7.7 - 15.4)' < 'Bajo (15.4 - 23.1)' < 'Regular (23.1 - 30.8)' ... 'Excepcional (69.2 - 76.9)' < 'Increíble (76.9 - 84.6)' < 'Extraordinario (84.6 - 92.3)' < 'Perfecto (92.3 - 100)']

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t_2= freq_tbl(dfc['host_acceptance_rate'])
t_2 = t_2.drop(['percentage','cumulative_perc'], axis=1)
t_2
#Creamos el filtro de los valores más representativos
f_2= t_2[t_2['frequency']>66]
#Ajustamos el indice del dataframe
f_2= f_2.set_index('host_acceptance_rate')
f_2
# Out:
#                               frequency
# host_acceptance_rate
# Perfecto (92.3 - 100)              3370
# Extraordinario (84.6 - 92.3)        317
# Increíble (76.9 - 84.6)             240

# %%
f_2.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='host_acceptance_rate'>

# %%
#Calculamos el numero total de la población "n"
dfc['host_total_listings_count']. info()
n3=4426
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4426 entries, 0 to 4425
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 4426 non-null   float64
# dtypes: float64(1)
# memory usage: 34.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
max3=dfc['host_total_listings_count'].max()
min3=dfc['host_total_listings_count'].min()
l3= [min3, max3]
l3
# Out:
# [1.0, 226.0]

# %%
r3=max3-min3
ni3= 1+3.32*np.log10(n3)
ni3
# Out:
# 13.104757879842914

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
in3=np.linspace(0.9, 226.1, 14)
in3
# Out:
# array([  0.9       ,  18.22307692,  35.54615385,  52.86923077,
#         70.19230769,  87.51538462, 104.83846154, 122.16153846,
#        139.48461538, 156.80769231, 174.13076923, 191.45384615,
#        208.77692308, 226.1       ])

# %%
c3 = ["Ocasional (0.9 - 18.2)", "Pequeño (18.2 - 35.5)", "Moderado (35.5 - 52.9)",  
        "Mediano (52.9 - 70.2)", "Grande (70.2 - 87.5)", "Muy grande (87.5 - 104.8)",  
        "Peq. empresa (104.8 - 122.2)", "Emp. mediana (122.2 - 139.5)", "Emp. grande (139.5 - 156.8)",  
        "Cadena peq. (156.8 - 174.1)", "Cadena med. (174.1 - 191.5)", "Cadena gra. (191.5 - 208.8)",  
        "Operador (208.8 - 226.1)"]

# %%
dfc['host_total_listings_count']=pd.cut(x= dfc['host_total_listings_count'], bins=in3, labels= c3)
dfc['host_total_listings_count']
# Out:
# 0         Ocasional (0.9 - 18.2)
# 1         Ocasional (0.9 - 18.2)
# 2         Ocasional (0.9 - 18.2)
# 3          Pequeño (18.2 - 35.5)
# 4          Pequeño (18.2 - 35.5)
#                   ...
# 4421      Moderado (35.5 - 52.9)
# 4422      Moderado (35.5 - 52.9)
# 4423    Operador (208.8 - 226.1)
# 4424      Ocasional (0.9 - 18.2)
# 4425      Moderado (35.5 - 52.9)
# Name: host_total_listings_count, Length: 4426, dtype: category
# Categories (13, object): ['Ocasional (0.9 - 18.2)' < 'Pequeño (18.2 - 35.5)' < 'Moderado (35.5 - 52.9)' < 'Mediano (52.9 - 70.2)' ... 'Cadena peq. (156.8 - 174.1)' < 'Cadena med. (174.1 - 191.5)' < 'Cadena gra. (191.5 - 208.8)' < 'Operador (208.8 - 226.1)']

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t_3= freq_tbl(dfc['host_total_listings_count'])
t_3 = t_3.drop(['percentage','cumulative_perc'], axis=1)
t_3
#Creamos el filtro de los valores más representativos
f_3= t_3[t_3['frequency']>191]
#Ajustamos el indice del dataframe
f_3= f_3.set_index('host_total_listings_count')
f_3
# Out:
#                            frequency
# host_total_listings_count
# Ocasional (0.9 - 18.2)          2270
# Moderado (35.5 - 52.9)           793
# Pequeño (18.2 - 35.5)            439
# Grande (70.2 - 87.5)             258

# %%
#Realizamos grafico de barras del dataframe filtrado
f_3.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Propiedades registradas de un anfitrion')
plt.xlabel('Tipo de anfitrion')
plt.ylabel('Cantidad de anfitriones')
# Out:
# Text(0, 0.5, 'Cantidad de anfitriones')

# %%
#Calculamos el numero total de la población "n"
dfc['accommodates']. info()
n4=4426
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4426 entries, 0 to 4425
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 4426 non-null   float64
# dtypes: float64(1)
# memory usage: 34.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
max4=dfc['accommodates'].max()
min4=dfc['accommodates'].min()
l4= [min4, max4]
l4
# Out:
# [1.0, 7.0]

# %%
r4=max4-min4
ni4= 1+3.32*np.log10(n4)
ni4
# Out:
# 13.104757879842914

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
in4=np.linspace(0.9, 7.1, 14)
in4
# Out:
# array([0.9       , 1.37692308, 1.85384615, 2.33076923, 2.80769231,
#        3.28461538, 3.76153846, 4.23846154, 4.71538462, 5.19230769,
#        5.66923077, 6.14615385, 6.62307692, 7.1       ])

# %%
c4 = ["Min. espacio (0.9 - 1.4)", "Muy pequeño (1.4 - 1.9)", "Pequeño (1.9 - 2.3)",  
        "Compacto (2.3 - 2.8)", "Justo (2.8 - 3.3)", "Moderado (3.3 - 3.8)",  
        "Cómodo (3.8 - 4.2)", "Amplio (4.2 - 4.7)", "Muy amplio (4.7 - 5.2)",  
        "Grande (5.2 - 5.7)", "Muy grande (5.7 - 6.1)", "Espacioso (6.1 - 6.6)",  
        "Extra espacioso (6.6 - 7.1)"]

# %%
dfc['accommodates']=pd.cut(x= dfc['accommodates'], bins=in4, labels= c4)
dfc['accommodates']
# Out:
# 0            Pequeño (1.9 - 2.3)
# 1            Pequeño (1.9 - 2.3)
# 2             Cómodo (3.8 - 4.2)
# 3            Pequeño (1.9 - 2.3)
# 4              Justo (2.8 - 3.3)
#                   ...
# 4421    Min. espacio (0.9 - 1.4)
# 4422    Min. espacio (0.9 - 1.4)
# 4423          Cómodo (3.8 - 4.2)
# 4424         Pequeño (1.9 - 2.3)
# 4425    Min. espacio (0.9 - 1.4)
# Name: accommodates, Length: 4426, dtype: category
# Categories (13, object): ['Min. espacio (0.9 - 1.4)' < 'Muy pequeño (1.4 - 1.9)' < 'Pequeño (1.9 - 2.3)' < 'Compacto (2.3 - 2.8)' ... 'Grande (5.2 - 5.7)' < 'Muy grande (5.7 - 6.1)' < 'Espacioso (6.1 - 6.6)' < 'Extra espacioso (6.6 - 7.1)']

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t_4= freq_tbl(dfc['accommodates'])
t_4 = t_4.drop(['percentage','cumulative_perc'], axis=1)
t_4
#Creamos el filtro de los valores más representativos
f_4= t_4[t_4['frequency']>303]
#Ajustamos el indice del dataframe
f_4= f_4.set_index('accommodates')
f_4
# Out:
#                           frequency
# accommodates
# Pequeño (1.9 - 2.3)            1851
# Cómodo (3.8 - 4.2)              782
# Min. espacio (0.9 - 1.4)        567
# Justo (2.8 - 3.3)               357

# %%
#Realizamos grafico de pastel del dataframe filtrado
f_4["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Calculamos el numero total de la población "n"
dfc['price']. info()
n5=4426
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4426 entries, 0 to 4425
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 4425 non-null   float64
# dtypes: float64(1)
# memory usage: 34.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
max5=dfc['price'].max()
min5=dfc['price'].min()
l5= [min5, max5]
l5
# Out:
# [25.0, 10000.0]

# %%
r5=max5-min5
ni5= 1+3.32*np.log10(n5)
ni5
# Out:
# 13.104757879842914

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
in5=np.linspace(24.9, 10000.1, 14)
in5
# Out:
# array([   24.9       ,   792.22307692,  1559.54615385,  2326.86923077,
#         3094.19230769,  3861.51538462,  4628.83846154,  5396.16153846,
#         6163.48461538,  6930.80769231,  7698.13076923,  8465.45384615,
#         9232.77692308, 10000.1       ])

# %%
c5 = ["Muy barato (24.9 - 792.2)", "Barato (792.2 - 1559.5)", "Económico (1559.5 - 2326.9)",  
        "Accesible (2326.9 - 3094.2)", "Moderado (3094.2 - 3861.5)", "Intermedio (3861.5 - 4628.8)",  
        "Algo costoso (4628.8 - 5396.2)", "Costoso (5396.2 - 6163.5)", "Muy costoso (6163.5 - 6930.8)",  
        "Premium (6930.8 - 7698.1)", "Exclusivo (7698.1 - 8465.5)", "Lujo (8465.5 - 9232.8)",  
        "Ultra lujo (9232.8 - 10000.1)"]

# %%
dfc['price']=pd.cut(x= dfc['price'], bins=in5, labels= c5)
dfc['price']
# Out:
# 0                             NaN
# 1       Muy barato (24.9 - 792.2)
# 2       Muy barato (24.9 - 792.2)
# 3       Muy barato (24.9 - 792.2)
# 4       Muy barato (24.9 - 792.2)
#                   ...
# 4421    Muy barato (24.9 - 792.2)
# 4422    Muy barato (24.9 - 792.2)
# 4423    Muy barato (24.9 - 792.2)
# 4424    Muy barato (24.9 - 792.2)
# 4425    Muy barato (24.9 - 792.2)
# Name: price, Length: 4426, dtype: category
# Categories (13, object): ['Muy barato (24.9 - 792.2)' < 'Barato (792.2 - 1559.5)' < 'Económico (1559.5 - 2326.9)' < 'Accesible (2326.9 - 3094.2)' ... 'Premium (6930.8 - 7698.1)' < 'Exclusivo (7698.1 - 8465.5)' < 'Lujo (8465.5 - 9232.8)' < 'Ultra lujo (9232.8 - 10000.1)']

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t_5= freq_tbl(dfc['price'])
t_5 = t_5.drop(['percentage','cumulative_perc'], axis=1)
t_5
#Creamos el filtro de los valores más representativos
f_5= t_5[t_5['frequency']>5]
#Ajustamos el indice del dataframe
f_5= f_5.set_index('price')
f_5
# Out:
#                              frequency
# price
# Muy barato (24.9 - 792.2)         4346
# Barato (792.2 - 1559.5)             66
# Económico (1559.5 - 2326.9)         10

# %%
f_5.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='price'>

# %%
#Calculamos el numero total de la población "n"
dfc['maximum_nights_avg_ntm']. info()
n6=4426
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4426 entries, 0 to 4425
# Series name: maximum_nights_avg_ntm
# Non-Null Count  Dtype
# --------------  -----
# 4426 non-null   float64
# dtypes: float64(1)
# memory usage: 34.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
max6=dfc['maximum_nights_avg_ntm'].max()
min6=dfc['maximum_nights_avg_ntm'].min()
l6= [min6, max6]
l6
# Out:
# [1.0, 1125.0]

# %%
r6=max6-min6
ni6= 1+3.32*np.log10(n6)
ni6
# Out:
# 13.104757879842914

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
in6=np.linspace(0.9, 1125.1, 14)
in6
# Out:
# array([9.00000000e-01, 8.73769231e+01, 1.73853846e+02, 2.60330769e+02,
#        3.46807692e+02, 4.33284615e+02, 5.19761538e+02, 6.06238462e+02,
#        6.92715385e+02, 7.79192308e+02, 8.65669231e+02, 9.52146154e+02,
#        1.03862308e+03, 1.12510000e+03])

# %%
c6 = ["Muy corto (1 - 80.4)", "Corto (80.4 - 159.8)", "Bajo (159.8 - 239.2)",  
        "Moderado bajo (239.2 - 318.7)", "Moderado (318.7 - 398.1)", "Intermedio bajo (398.1 - 477.5)",  
        "Intermedio (477.5 - 556.9)", "Intermedio alto (556.9 - 636.3)", "Alto (636.3 - 715.8)",  
        "Muy alto (715.8 - 795.2)", "Extremo bajo (795.2 - 874.6)", "Extremo (874.6 - 954.0)",  
        "Muy extremo (954.0 - 1033.4)"]

# %%
dfc['maximum_nights_avg_ntm']=pd.cut(x= dfc['maximum_nights_avg_ntm'], bins=in6, labels= c6)
dfc['maximum_nights_avg_ntm']
# Out:
# 0       Muy extremo (954.0 - 1033.4)
# 1       Muy extremo (954.0 - 1033.4)
# 2               Alto (636.3 - 715.8)
# 3           Moderado (318.7 - 398.1)
# 4       Muy extremo (954.0 - 1033.4)
#                     ...
# 4421        Moderado (318.7 - 398.1)
# 4422        Moderado (318.7 - 398.1)
# 4423        Moderado (318.7 - 398.1)
# 4424        Moderado (318.7 - 398.1)
# 4425        Moderado (318.7 - 398.1)
# Name: maximum_nights_avg_ntm, Length: 4426, dtype: category
# Categories (13, object): ['Muy corto (1 - 80.4)' < 'Corto (80.4 - 159.8)' < 'Bajo (159.8 - 239.2)' < 'Moderado bajo (239.2 - 318.7)' ... 'Muy alto (715.8 - 795.2)' < 'Extremo bajo (795.2 - 874.6)' < 'Extremo (874.6 - 954.0)' < 'Muy extremo (954.0 - 1033.4)']

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t_6= freq_tbl(dfc['maximum_nights_avg_ntm'])
t_6 = t_6.drop(['percentage','cumulative_perc'], axis=1)
t_6
#Creamos el filtro de los valores más representativos
f_6= t_6[t_6['frequency']>152]
#Ajustamos el indice del dataframe
f_6= f_6.set_index('maximum_nights_avg_ntm')
f_6
# Out:
#                               frequency
# maximum_nights_avg_ntm
# Muy extremo (954.0 - 1033.4)       2052
# Moderado (318.7 - 398.1)           1458
# Muy corto (1 - 80.4)                298
# Corto (80.4 - 159.8)                200

# %%
#Realizamos grafico de barras del dataframe filtrado
f_6.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Promedio de estancias por anfitrión')
plt.xlabel('Duración máxima de noches')
plt.ylabel('Cantidad de anfitriones')
# Out:
# Text(0, 0.5, 'Cantidad de anfitriones')

# %%
#Calculamos el numero total de la población "n"
dfc['number_of_reviews']. info()
n7=4426
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4426 entries, 0 to 4425
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 4426 non-null   float64
# dtypes: float64(1)
# memory usage: 34.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
max7=dfc['number_of_reviews'].max()
min7=dfc['number_of_reviews'].min()
l7= [min7, max7]
l7
# Out:
# [0.0, 141.0]

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
in7=np.linspace(0.0, 141.1, 14)
in7
# Out:
# array([  0.        ,  10.85384615,  21.70769231,  32.56153846,
#         43.41538462,  54.26923077,  65.12307692,  75.97692308,
#         86.83076923,  97.68461538, 108.53846154, 119.39230769,
#        130.24615385, 141.1       ])

# %%
c7 = ["Ninguna (0 - 10.9)", "Muy pocas (10.9 - 21.7)", "Pocas (21.7 - 32.6)",  
        "Algunas (32.6 - 43.4)", "Moderadas (43.4 - 54.3)", "Bastantes (54.3 - 65.1)",  
        "Muchas (65.1 - 75.9)", "Muy muchas (75.9 - 86.8)", "Numerosas (86.8 - 97.7)",  
        "Muchísimas (97.7 - 108.5)", "Extensas (108.5 - 119.4)", "Grandes (119.4 - 130.2)",  
        "Muy grandes (130.2 - 141.1)"]

# %%
dfc['number_of_reviews']=pd.cut(x= dfc['number_of_reviews'], bins=in7, labels= c7)
dfc['number_of_reviews']
# Out:
# 0               Pocas (21.7 - 32.6)
# 1       Muy grandes (130.2 - 141.1)
# 2       Muy grandes (130.2 - 141.1)
# 3               Pocas (21.7 - 32.6)
# 4                Ninguna (0 - 10.9)
#                    ...
# 4421                            NaN
# 4422                            NaN
# 4423                            NaN
# 4424                            NaN
# 4425                            NaN
# Name: number_of_reviews, Length: 4426, dtype: category
# Categories (13, object): ['Ninguna (0 - 10.9)' < 'Muy pocas (10.9 - 21.7)' < 'Pocas (21.7 - 32.6)' < 'Algunas (32.6 - 43.4)' ... 'Muchísimas (97.7 - 108.5)' < 'Extensas (108.5 - 119.4)' < 'Grandes (119.4 - 130.2)' < 'Muy grandes (130.2 - 141.1)']

# %%
#Obtenemos un análisis univariado de la variable categórica y eliminamos las columnas "percentage" y "cumulative_perc"
t_7= freq_tbl(dfc['number_of_reviews'])
t_7 = t_7.drop(['percentage','cumulative_perc'], axis=1)
t_7
#Creamos el filtro de los valores más representativos
f_7= t_7[t_7['frequency']>155]
#Ajustamos el indice del dataframe
f_7= f_7.set_index('number_of_reviews')
f_7
# Out:
#                          frequency
# number_of_reviews
# Ninguna (0 - 10.9)            1245
# Pocas (21.7 - 32.6)            786
# Muy pocas (10.9 - 21.7)        405
# Algunas (32.6 - 43.4)          215

# %%
#Realizamos grafico de pastel del dataframe filtrado
f_7["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%", title='Número de reseñas')
# Out:
# <Axes: title={'center': 'Número de reseñas'}, ylabel='frequency'>
